# %%
# Imports
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
import urllib.parse
import undetected_chromedriver as uc

import os
import time
from bs4 import BeautifulSoup
import re
import pandas as pd
import requests

# %%
# Configure Chrome Webdriver

chrome_install = ChromeDriverManager().install()

# %%
# Initialize Chrome WebDriver
options = webdriver.ChromeOptions()
#options.add_argument('--headless')

options.add_argument(
    "--user-agent=Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like Mac OS X) "
    "AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Mobile/15E148 Safari/604.1"
)

browser = webdriver.Chrome(options=options)

# %%
# Setup search parameters
city = "montreal"
product = "Gaming PC"
min_price = 0
max_price = 5000
days_listed = 7
MAX_SCROLLS = 4

# %%
# Setup base URL
url = f'https://www.facebook.com/marketplace/{city}/search?query={product}&minPrice={min_price}&maxPrice={max_price}&daysSinceListed={days_listed}&sortBy=creation_time_descend&exact=false'

# Visit website
browser.get(url)

# Close login pop-up
try:
    close_button = browser.find_element(By.XPATH, "//div[@aria-label='Close']")
    close_button.click()
    print("Login prompt closed successfully...")
except:
    print("Login prompt not closed correctly...")
    pass
# Out:
# Login prompt not closed correctly...

# %%
# Scroll down to load all results
wait = WebDriverWait(browser, 10) # pause execution until condition is true w/ timotu limit

last_height = int(browser.execute_script("return document.body.scrollHeight"))
MIN_DELTA = 50  # minimum height change to count as "new content"

for i in range(MAX_SCROLLS):
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(0.1)

    try:
        wait.until(
            lambda d: int(d.execute_script("return document.body.scrollHeight")) - last_height > MIN_DELTA
        )
        new_height = int(browser.execute_script("return document.body.scrollHeight"))
        print("Scroller successful:", new_height)
        last_height = new_height

    except TimeoutException:
        print("No further increase in scrollHeight. Stopping.")
        break

print("Finished Scrolling...")
# Out:
# Scroller successful: 5848
# Scroller successful: 8839
# Scroller successful: 11789
# Scroller successful: 14800
# Finished Scrolling...

# %%
# Retrieve the HTML
html = browser.page_source

soup = BeautifulSoup(html, 'html.parser')

browser.close()

# %%
# Find link elements
links = soup.find_all('a')

# Filter on product keyword only
product_links = [
    link for link in links
    if product.lower() in link.text.lower()
    #if city_link.lower() in link.text.lower()
]

product_data = []

for product_link in product_links:
    url = product_link.get('href')
    if not url:
        continue
    text = '\n'.join(product_link.stripped_strings)
    product_data.append({'url': url, 'text': text})
# Out:
# [{'url': '/marketplace/item/870259832329433/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$469\nBudget Gaming PC with Master Roshi\nMontréal, QC'},
#  {'url': '/marketplace/item/1352520299338565/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$650\nGaming pc\nMont-Royal, QC'},
#  {'url': '/marketplace/item/825359173598814/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$710\nRTX 2080Ti/ i7-7700 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/1991714498056219/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$400\nEntry level gaming pc\nMontréal, QC'},
#  {'url': '/marketplace/item/2070007520494657/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$419\nBudget Gaming PC with Goku\nMontréal, QC'},
#  {'url': '/marketplace/item/730707916057808/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$400\nGAMING PC (VENTE RAPIDE/NEGOCIABLE)\nMontréal, QC'},
#  {'url': '/marketplace/item/1698603451524564/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$550\nGaming PC\nMontréal-Ouest, QC'},
#  {'url': '/marketplace/item/1312220617585993/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$890\nGaming Pc 5600x / 3070 Ti\nMontréal, QC'},
#  {'url': '/marketplace/item/1951798672346399/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,220\nRYX 3080Ti/ Intel i9 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/1350243379360070/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,900\nRTX 5070 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/849825777450160/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$3,000\nGaming PC - 4080super - Ryzen 7\nMontréal, QC'},
#  {'url': '/marketplace/item/1533093771036124/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$250\nGaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/24439724409035682/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,200\nGAMING PC + SET UP\nMontréal, QC'},
#  {'url': '/marketplace/item/1501267610988406/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,800\nRTX 5070 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/1853701238842670/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,500\nGaming Pc\nMontréal, QC'},
#  {'url': '/marketplace/item/699210539904270/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nITX SFF AM4 WIFI Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/823742183595599/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,900\nRTX 5070 Gaming PC\nBrossard, QC'},
#  {'url': '/marketplace/item/1455429009346545/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$550\nCA$650\nGAMING PC FOR SALE ‼️\nMontréal, QC'},
#  {'url': '/marketplace/item/1965514277342404/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,150\nGaming PC – i5-13400F / RTX 3070\nMirabel, QC'},
#  {'url': '/marketplace/item/1921184702155542/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,100\nAM5 Ryzen RTX 3070 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/1422370902618567/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$850\nCA$900\nGaming PC   RTX3070 | i5 12400F\nMontréal, QC'},
#  {'url': '/marketplace/item/1335423211381752/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$400\nCA$600\nGaming pc\nKirkland, QC'},
#  {'url': '/marketplace/item/825009770280955/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nRTX 3070 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/1137312048510518/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$420\nIntel i7 Gaming PC w/ 960GB NVMe\nMontréal, QC'},
#  {'url': '/marketplace/item/2050484122353784/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$820\nRTX 3060 gaming pc\nLaval, QC'},
#  {'url': '/marketplace/item/1144654081149156/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$750\nGaming pc\nLaval, QC'},
#  {'url': '/marketplace/item/4251379785143360/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$4,500\nCA$5,000\nGaming pc\nMontréal, QC'},
#  {'url': '/marketplace/item/2303931056700711/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$425\nCA$450\nGaming PC • GTX 1080 Ti • Ryzen • 32G RAM • Mini-ITX• 512Go SSD\nMontréal, QC'},
#  {'url': '/marketplace/item/1554236482682615/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$600\nCA$700\nGaming pc\nMontréal, QC'},
#  {'url': '/marketplace/item/1194509795877975/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nCyberpower Gaming Pc\nMontréal, QC'},
#  {'url': '/marketplace/item/1521040739020093/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nGaming PC i-11700k rtx 3070\nMontréal, QC'},
#  {'url': '/marketplace/item/1211914670782541/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,850\nRTX 5070 Gaming PC\nBrossard, QC'},
#  {'url': '/marketplace/item/1896615574584985/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$680\nGaming PC – Ryzen 5 / RTX 2060 / 16GB RAM\nLongueuil, QC'},
#  {'url': '/marketplace/item/1998635850920398/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,500\nPOWERFUL gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/847140027807293/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$880\nRTX Gaming PC\nLongueuil, QC'},
#  {'url': '/marketplace/item/1186948702900164/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$2,850\n7800X3D 5070TI 64GB 4TB Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/868655425727535/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$900\nGaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/897710430087954/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$600\nCA$630\nBudget Gaming PC / 100+ fps 1080p\nMontréal, QC'},
#  {'url': '/marketplace/item/1874497953502799/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$2,060\nRTX 4070TI Super/ I7-13700f/ DDR5 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/673269178997361/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,750\nGaming PC build 14600K 9060 XT 16GB\nDorval, QC'},
#  {'url': '/marketplace/item/24979278928390561/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$600\ngaming pc\nMontréal, QC'},
#  {'url': '/marketplace/item/2388769944896215/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$3,399\nNEUF: 5080 gaming pc\nBrossard, QC'},
#  {'url': '/marketplace/item/3354757394701896/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,575\nGaming pc\nSt-Eustache, QC'},
#  {'url': '/marketplace/item/867696585599851/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$2,500\nCustom Built Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/1240144714805750/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$400\nGaming PC and accessories\nSouth Glengarry, ON'},
#  {'url': '/marketplace/item/1505478320572952/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$150\nDeepcool ch780 gaming pc case\nMontréal, QC'},
#  {'url': '/marketplace/item/3918249365140739/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,250\nCustom Gaming PC – i7-10700F • RTX 3080 • 16GB RAM • 953GB SSD\nMontréal, QC'},
#  {'url': '/marketplace/item/2076311876446988/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$550\nGaming PC - Asus ROG Strix GT15\nPointe-Claire, QC'},
#  {'url': '/marketplace/item/1983401515830874/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,099\nGaming PC with a 3070 GPU NON-LHR (specs in description)\nMontréal, QC'},
#  {'url': '/marketplace/item/1868669900428484/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$50\nI can build your Custom Gaming Pc / Help you pick parts\nMontréal, QC'},
#  {'url': '/marketplace/item/1684825649159829/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$2,970\nRTX 5080/ RYZEN 7 7800x3d/ DDR5 Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/867029975909119/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,200\nRtx 3080 / Ryzen 5 5600X Gaming Pc\nMontréal, QC'},
#  {'url': '/marketplace/item/2077808706358343/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,700\nCA$2,500\nBRAND NEW GAMING PC\nDollard-des Ormeaux, QC'},
#  {'url': '/marketplace/item/2840280599496101/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,600\nCA$2,000\nHP OMEN 45L Gaming PC – RTX 3080 Ti / i9-12900K / 32GB / 1TB SSD NVME– POWERHOUSE\nSte-Marthe-sur-le-Lac, QC'},
#  {'url': '/marketplace/item/4177585855788704/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$2,200\nCA$2,650\nRtx 5080 Gaming pc\nOttawa, ON'},
#  {'url': '/marketplace/item/808514012081040/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,000\nGaming PC\nPointe-Claire, QC'},
#  {'url': '/marketplace/item/1337327217896481/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nGaming Pc  rtx 3060 ti + 12 gen cpu\nMontréal, QC'},
#  {'url': '/marketplace/item/1157779833004883/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$600\nCA$700\nUsed Gaming PC\nLavaltrie, QC'},
#  {'url': '/marketplace/item/2028307857984183/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$2,350\nGaming PC RTX 4070 TI SUPER R7 7800X3D\nMontréal, QC'},
#  {'url': '/marketplace/item/4311116465786016/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$780\nGaming pc rtx 3060ti et i5 12400 12 gen\nMont-Royal, QC'},
#  {'url': '/marketplace/item/1319133739526169/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$3,500\nGaming pc 5070 ti - plug and play (new)\nMontréal, QC'},
#  {'url': '/marketplace/item/1518184706126088/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nGaming pc\nVarennes, QC'},
#  {'url': '/marketplace/item/992673213065591/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$670\nGaming Pc | RTX 2060 SUPER | RYZEN 5 4500 | 16GB RAM | 512GB SSD | WINDOWS 11 |\nMontréal, QC'},
#  {'url': '/marketplace/item/1908282453083555/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$875\nCA$950\nNew gaming pc rtx 2070 super\nDollard-des Ormeaux, QC'},
#  {'url': '/marketplace/item/1756111878440762/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,000\nAlienware Aurora R12 - gaming PC & work PC\nLaval, QC'},
#  {'url': '/marketplace/item/1342816530944657/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,600\nRtx 3080 / Ryzen 7 7700X Ddr5 Gaming Pc\nMontréal, QC'},
#  {'url': '/marketplace/item/770935132643104/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$3,500\nHIGH END GAMING PC / ASUS 5080 / 9800X3D / LIAN LI VISION 011\nSte-Sophie, QC'},
#  {'url': '/marketplace/item/1616783659291530/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$700\nCA$800\nFull Gaming Pc setup\nCornwall, ON'},
#  {'url': '/marketplace/item/1909502586587605/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,100\nNZXT H1 Gaming PC Setup\nOttawa, ON'},
#  {'url': '/marketplace/item/1164737998470129/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,500\nGaming Pc modern retro emulation games\nLaval, QC'},
#  {'url': '/marketplace/item/1150922037147463/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$769\nHigh Performance Gaming PC\nMontréal, QC'},
#  {'url': '/marketplace/item/5127465030812232/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$800\nGaming PC RTX 3060 + 144Hz Monitor – Plug & Play, Great Condition\nBois-des-Filion, QC'},
#  {'url': '/marketplace/item/771946172565952/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'CA$1,750\nCA$2,100\nGaming pc\nSte-Marthe-sur-le-Lac, QC'}]

# %%
# Create an empty list to store product data
extracted_data = []

for item in product_data:
    lines = item['text'].split('\n')

    # Regular expression to find numeric values
    numeric_pattern = re.compile('\d[\d,.]*')
    
    # Extracting prices
    # Iterate through lines to find the first line with numbers
    for line in lines:
        match = numeric_pattern.search(line)
        if match:    
            # Extract the first numeric value found
            price_str = match.group()
            # Convert price to float (handle commas)
            price = float(price_str.replace(',',''))
            break
        
    # Extract title
    title = lines[-2]

    # Extract location
    location = lines[-1]

    # Add extracted data to a list of dictionaries
    extracted_data.append({
        'title': title,
        'price': price,
        'location': location,
        'url': re.sub(r'\?.*', '', item['url'])
    })
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/xn/w_xnr1cn1jq5m_6rgnybnsc40000gn/T/ipykernel_3546/1369819200.py:8: SyntaxWarning: invalid escape sequence '\d'
#   numeric_pattern = re.compile('\d[\d,.]*')

# %%
extracted_data
# Out:
# [{'title': 'Budget Gaming PC with Master Roshi',
#   'price': 469.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/870259832329433/'},
#  {'title': 'Gaming pc',
#   'price': 650.0,
#   'location': 'Mont-Royal, QC',
#   'url': '/marketplace/item/1352520299338565/'},
#  {'title': 'RTX 2080Ti/ i7-7700 Gaming PC',
#   'price': 710.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/825359173598814/'},
#  {'title': 'Entry level gaming pc',
#   'price': 400.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1991714498056219/'},
#  {'title': 'Budget Gaming PC with Goku',
#   'price': 419.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/2070007520494657/'},
#  {'title': 'GAMING PC (VENTE RAPIDE/NEGOCIABLE)',
#   'price': 400.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/730707916057808/'},
#  {'title': 'Gaming PC',
#   'price': 550.0,
#   'location': 'Montréal-Ouest, QC',
#   'url': '/marketplace/item/1698603451524564/'},
#  {'title': 'Gaming Pc 5600x / 3070 Ti',
#   'price': 890.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1312220617585993/'},
#  {'title': 'RYX 3080Ti/ Intel i9 Gaming PC',
#   'price': 1220.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1951798672346399/'},
#  {'title': 'RTX 5070 Gaming PC',
#   'price': 1900.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1350243379360070/'},
#  {'title': 'Gaming PC - 4080super - Ryzen 7',
#   'price': 3000.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/849825777450160/'},
#  {'title': 'Gaming PC',
#   'price': 250.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1533093771036124/'},
#  {'title': 'GAMING PC + SET UP',
#   'price': 1200.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/24439724409035682/'},
#  {'title': 'RTX 5070 Gaming PC',
#   'price': 1800.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1501267610988406/'},
#  {'title': 'Gaming Pc',
#   'price': 1500.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1853701238842670/'},
#  {'title': 'ITX SFF AM4 WIFI Gaming PC',
#   'price': 700.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/699210539904270/'},
#  {'title': 'RTX 5070 Gaming PC',
#   'price': 1900.0,
#   'location': 'Brossard, QC',
#   'url': '/marketplace/item/823742183595599/'},
#  {'title': 'GAMING PC FOR SALE ‼️',
#   'price': 550.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1455429009346545/'},
#  {'title': 'Gaming PC – i5-13400F / RTX 3070',
#   'price': 1150.0,
#   'location': 'Mirabel, QC',
#   'url': '/marketplace/item/1965514277342404/'},
#  {'title': 'AM5 Ryzen RTX 3070 Gaming PC',
#   'price': 1100.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1921184702155542/'},
#  {'title': 'Gaming PC   RTX3070 | i5 12400F',
#   'price': 850.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1422370902618567/'},
#  {'title': 'Gaming pc',
#   'price': 400.0,
#   'location': 'Kirkland, QC',
#   'url': '/marketplace/item/1335423211381752/'},
#  {'title': 'RTX 3070 Gaming PC',
#   'price': 700.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/825009770280955/'},
#  {'title': 'Intel i7 Gaming PC w/ 960GB NVMe',
#   'price': 420.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1137312048510518/'},
#  {'title': 'RTX 3060 gaming pc',
#   'price': 820.0,
#   'location': 'Laval, QC',
#   'url': '/marketplace/item/2050484122353784/'},
#  {'title': 'Gaming pc',
#   'price': 750.0,
#   'location': 'Laval, QC',
#   'url': '/marketplace/item/1144654081149156/'},
#  {'title': 'Gaming pc',
#   'price': 4500.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/4251379785143360/'},
#  {'title': 'Gaming PC • GTX 1080 Ti • Ryzen • 32G RAM • Mini-ITX• 512Go SSD',
#   'price': 425.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/2303931056700711/'},
#  {'title': 'Gaming pc',
#   'price': 600.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1554236482682615/'},
#  {'title': 'Cyberpower Gaming Pc',
#   'price': 700.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1194509795877975/'},
#  {'title': 'Gaming PC i-11700k rtx 3070',
#   'price': 700.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1521040739020093/'},
#  {'title': 'RTX 5070 Gaming PC',
#   'price': 1850.0,
#   'location': 'Brossard, QC',
#   'url': '/marketplace/item/1211914670782541/'},
#  {'title': 'Gaming PC – Ryzen 5 / RTX 2060 / 16GB RAM',
#   'price': 680.0,
#   'location': 'Longueuil, QC',
#   'url': '/marketplace/item/1896615574584985/'},
#  {'title': 'POWERFUL gaming PC',
#   'price': 1500.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1998635850920398/'},
#  {'title': 'RTX Gaming PC',
#   'price': 880.0,
#   'location': 'Longueuil, QC',
#   'url': '/marketplace/item/847140027807293/'},
#  {'title': '7800X3D 5070TI 64GB 4TB Gaming PC',
#   'price': 2850.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1186948702900164/'},
#  {'title': 'Gaming PC',
#   'price': 900.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/868655425727535/'},
#  {'title': 'Budget Gaming PC / 100+ fps 1080p',
#   'price': 600.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/897710430087954/'},
#  {'title': 'RTX 4070TI Super/ I7-13700f/ DDR5 Gaming PC',
#   'price': 2060.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1874497953502799/'},
#  {'title': 'Gaming PC build 14600K 9060 XT 16GB',
#   'price': 1750.0,
#   'location': 'Dorval, QC',
#   'url': '/marketplace/item/673269178997361/'},
#  {'title': 'gaming pc',
#   'price': 600.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/24979278928390561/'},
#  {'title': 'NEUF: 5080 gaming pc',
#   'price': 3399.0,
#   'location': 'Brossard, QC',
#   'url': '/marketplace/item/2388769944896215/'},
#  {'title': 'Gaming pc',
#   'price': 1575.0,
#   'location': 'St-Eustache, QC',
#   'url': '/marketplace/item/3354757394701896/'},
#  {'title': 'Custom Built Gaming PC',
#   'price': 2500.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/867696585599851/'},
#  {'title': 'Gaming PC and accessories',
#   'price': 400.0,
#   'location': 'South Glengarry, ON',
#   'url': '/marketplace/item/1240144714805750/'},
#  {'title': 'Deepcool ch780 gaming pc case',
#   'price': 150.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1505478320572952/'},
#  {'title': 'Custom Gaming PC – i7-10700F • RTX 3080 • 16GB RAM • 953GB SSD',
#   'price': 1250.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/3918249365140739/'},
#  {'title': 'Gaming PC - Asus ROG Strix GT15',
#   'price': 550.0,
#   'location': 'Pointe-Claire, QC',
#   'url': '/marketplace/item/2076311876446988/'},
#  {'title': 'Gaming PC with a 3070 GPU NON-LHR (specs in description)',
#   'price': 1099.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1983401515830874/'},
#  {'title': 'I can build your Custom Gaming Pc / Help you pick parts',
#   'price': 50.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1868669900428484/'},
#  {'title': 'RTX 5080/ RYZEN 7 7800x3d/ DDR5 Gaming PC',
#   'price': 2970.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1684825649159829/'},
#  {'title': 'Rtx 3080 / Ryzen 5 5600X Gaming Pc',
#   'price': 1200.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/867029975909119/'},
#  {'title': 'BRAND NEW GAMING PC',
#   'price': 1700.0,
#   'location': 'Dollard-des Ormeaux, QC',
#   'url': '/marketplace/item/2077808706358343/'},
#  {'title': 'HP OMEN 45L Gaming PC – RTX 3080 Ti / i9-12900K / 32GB / 1TB SSD NVME– POWERHOUSE',
#   'price': 1600.0,
#   'location': 'Ste-Marthe-sur-le-Lac, QC',
#   'url': '/marketplace/item/2840280599496101/'},
#  {'title': 'Rtx 5080 Gaming pc',
#   'price': 2200.0,
#   'location': 'Ottawa, ON',
#   'url': '/marketplace/item/4177585855788704/'},
#  {'title': 'Gaming PC',
#   'price': 1000.0,
#   'location': 'Pointe-Claire, QC',
#   'url': '/marketplace/item/808514012081040/'},
#  {'title': 'Gaming Pc  rtx 3060 ti + 12 gen cpu',
#   'price': 700.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1337327217896481/'},
#  {'title': 'Used Gaming PC',
#   'price': 600.0,
#   'location': 'Lavaltrie, QC',
#   'url': '/marketplace/item/1157779833004883/'},
#  {'title': 'Gaming PC RTX 4070 TI SUPER R7 7800X3D',
#   'price': 2350.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/2028307857984183/'},
#  {'title': 'Gaming pc rtx 3060ti et i5 12400 12 gen',
#   'price': 780.0,
#   'location': 'Mont-Royal, QC',
#   'url': '/marketplace/item/4311116465786016/'},
#  {'title': 'Gaming pc 5070 ti - plug and play (new)',
#   'price': 3500.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1319133739526169/'},
#  {'title': 'Gaming pc',
#   'price': 700.0,
#   'location': 'Varennes, QC',
#   'url': '/marketplace/item/1518184706126088/'},
#  {'title': 'Gaming Pc | RTX 2060 SUPER | RYZEN 5 4500 | 16GB RAM | 512GB SSD | WINDOWS 11 |',
#   'price': 670.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/992673213065591/'},
#  {'title': 'New gaming pc rtx 2070 super',
#   'price': 875.0,
#   'location': 'Dollard-des Ormeaux, QC',
#   'url': '/marketplace/item/1908282453083555/'},
#  {'title': 'Alienware Aurora R12 - gaming PC & work PC',
#   'price': 1000.0,
#   'location': 'Laval, QC',
#   'url': '/marketplace/item/1756111878440762/'},
#  {'title': 'Rtx 3080 / Ryzen 7 7700X Ddr5 Gaming Pc',
#   'price': 1600.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1342816530944657/'},
#  {'title': 'HIGH END GAMING PC / ASUS 5080 / 9800X3D / LIAN LI VISION 011',
#   'price': 3500.0,
#   'location': 'Ste-Sophie, QC',
#   'url': '/marketplace/item/770935132643104/'},
#  {'title': 'Full Gaming Pc setup',
#   'price': 700.0,
#   'location': 'Cornwall, ON',
#   'url': '/marketplace/item/1616783659291530/'},
#  {'title': 'NZXT H1 Gaming PC Setup',
#   'price': 1100.0,
#   'location': 'Ottawa, ON',
#   'url': '/marketplace/item/1909502586587605/'},
#  {'title': 'Gaming Pc modern retro emulation games',
#   'price': 1500.0,
#   'location': 'Laval, QC',
#   'url': '/marketplace/item/1164737998470129/'},
#  {'title': 'High Performance Gaming PC',
#   'price': 769.0,
#   'location': 'Montréal, QC',
#   'url': '/marketplace/item/1150922037147463/'},
#  {'title': 'Gaming PC RTX 3060 + 144Hz Monitor – Plug & Play, Great Condition',
#   'price': 800.0,
#   'location': 'Bois-des-Filion, QC',
#   'url': '/marketplace/item/5127465030812232/'},
#  {'title': 'Gaming pc',
#   'price': 1750.0,
#   'location': 'Ste-Marthe-sur-le-Lac, QC',
#   'url': '/marketplace/item/771946172565952/'}]
