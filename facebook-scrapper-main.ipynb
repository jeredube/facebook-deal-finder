# %%
# Imports
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException
import urllib.parse
import undetected_chromedriver as uc

import os
import time
from bs4 import BeautifulSoup
import re
import pandas as pd
import requests

# %%
# Configure Chrome Webdriver

chrome_install = ChromeDriverManager().install()

# %%
# Initialize Chrome WebDriver
options = webdriver.ChromeOptions()
#options.add_argument('--headless')

options.add_argument(
    "--user-agent=Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like Mac OS X) "
    "AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Mobile/15E148 Safari/604.1"
)

browser = webdriver.Chrome(options=options)

# %%
# Setup search parameters
city = "montreal"
product = "Gaming PC"
min_price = 0
max_price = 5000
days_listed = 7
MAX_SCROLLS = 4

# %%
# Setup base URL
url = f'https://www.facebook.com/marketplace/{city}/search?query={product}&minPrice={min_price}&maxPrice={max_price}&daysSinceListed={days_listed}&sortBy=creation_time_descend&exact=false'

# Visit website
browser.get(url)

# Close login pop-up
try:
    close_button = browser.find_element(By.XPATH, "//div[@aria-label='Close']")
    close_button.click()
    print("Login prompt closed successfully...")
except:
    print("Login prompt not closed correctly...")
    pass
# Out:
# Login prompt not closed correctly...

# %%
# Scroll down to load all results
wait = WebDriverWait(browser, 10) # pause execution until condition is true w/ timotu limit

last_height = int(browser.execute_script("return document.body.scrollHeight"))
MIN_DELTA = 50  # minimum height change to count as "new content"

for i in range(MAX_SCROLLS):
    browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(0.1)

    try:
        wait.until(
            lambda d: int(d.execute_script("return document.body.scrollHeight")) - last_height > MIN_DELTA
        )
        new_height = int(browser.execute_script("return document.body.scrollHeight"))
        print("Scroller successful:", new_height)
        last_height = new_height

    except TimeoutException:
        print("No further increase in scrollHeight. Stopping.")
        break

print("Finished Scrolling...")
# Out:
# Scroller successful: 5856
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[100], line 18
#      16     print("Scroller successful:", new_height)
#      17     last_height = new_height
# ---> 18     time.sleep(100)
#      20 except TimeoutException:
#      21     print("No further increase in scrollHeight. Stopping.")
#
# KeyboardInterrupt:

# %%
# Retrieve the HTML
html = browser.page_source

soup = BeautifulSoup(html, 'html.parser')

browser.close()

# %%
# Find link elements
links = soup.find_all('a')

# Filter on product keyword only
product_links = [
    link for link in links
    if product.lower() in link.text.lower()
    #if city_link.lower() in link.text.lower()
]

product_data = []

for product_link in product_links:
    url = product_link.get('href')
    if not url:
        continue
    text = '\n'.join(product_link.stripped_strings)
    product_data.append({'url': url, 'text': text})

#print(len(product_links), "links matched")
#print(len(product_data), "items collected")

product_data
# Out:
# [{'url': '/marketplace/item/1936327400277652/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$800\nSelling a Gaming PC!\nOakland, CA'},
#  {'url': '/marketplace/item/901321479028474/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$800\nGaming pc\nSan Francisco, CA'},
#  {'url': '/marketplace/item/810831765100576/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$800\nGaming Pc\nSan Francisco, CA'},
#  {'url': '/marketplace/item/4211399239137993/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$649\nGaming PC\nSan Francisco, CA'},
#  {'url': '/marketplace/item/826444880106126/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$250\nDell OptiPlex Gaming PC\nSan Francisco, CA'},
#  {'url': '/marketplace/item/2347540209049347/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$900\n$1,000\nGaming PC with a 3070ti\nSan Francisco, CA'},
#  {'url': '/marketplace/item/1132546485748395/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$1,900\nHigh-End Gaming PC – RTX 5070, i7-12700KF, 32GB DDR5, 3TB SSD, RGB\nSan Francisco, CA'},
#  {'url': '/marketplace/item/733386452439995/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$400\nGAMING PC\nTurlock, CA'},
#  {'url': '/marketplace/item/821143860832517/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$300\nGaming PC – Ryzen 7 / GTX 1050 Ti / 16GB RAM / 1TB – Great Starter Build\nPittsburg, CA'},
#  {'url': '/marketplace/item/814885354858152/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$100\n$210\nGaming Pc\nLivermore, CA'},
#  {'url': '/marketplace/item/2340733113065321/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$300\n$350\nGTX 1660 ti, Ryzen 5 3600 Gaming PC\nDaly City, CA'},
#  {'url': '/marketplace/item/1145219074420994/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$250\nRX 580 Gaming PC\nOakland, CA'},
#  {'url': '/marketplace/item/1603077891123313/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$2,999\nBrand new High End Gaming PC - Nvidia RTX 5080 / AMD 9800x3d\nHayward, CA'},
#  {'url': '/marketplace/item/1548897519465645/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$30\nIncomplete gaming PC project\nBenicia, CA'},
#  {'url': '/marketplace/item/1766347714079720/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$1,000\nGaming PC\nFresno, CA'},
#  {'url': '/marketplace/item/1166447678336128/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$449\niBUYPOWER Pro Gaming PC (+ Free monitor!) | i9-9900K, RTX 2070 8GB\nSan Francisco, CA'},
#  {'url': '/marketplace/item/4107574722722717/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$525\nCustom Gaming PC // i7-12700k // 32GB RAM //1080 GTX\nEl Cerrito, CA'},
#  {'url': '/marketplace/item/808432582101480/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$875\nGaming PC Computers for sale (3)! esports up to AAA 4k performance!\nSan Francisco, CA'},
#  {'url': '/marketplace/item/1200893358635057/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$200\nGaming pc\nFairfield, CA'},
#  {'url': '/marketplace/item/1202289165053637/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$650\n$750\nGaming PC AMD 5700x / MSI 3070 GPU\nSan Francisco, CA'},
#  {'url': '/marketplace/item/1342125647645733/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$600\n$700\nHigh-End Gaming PC – i7-9700K – TITAN X 12 GB – 32 GB RAM – 2 TB SSD – 1440p / 4K\nSan Francisco, CA'},
#  {'url': '/marketplace/item/1361103482261687/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$3,300\nVENGEANCE Prebuilt Gaming PC\nSan Francisco, CA'},
#  {'url': '/marketplace/item/842281425151549/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$795\nGAMING PC - i7 11700K - RTX 3060 12GB\nSan Francisco, CA'},
#  {'url': '/marketplace/item/1546250043374782/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$450\n$550\nGaming pc gtx1080 comes with monitor keyboard mouse\nFairfield, CA'},
#  {'url': '/marketplace/item/1267204801796462/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$1\nCustom Gaming PC Built for Any Budget\nSanta Rosa, CA'},
#  {'url': '/marketplace/item/848911157696743/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$300\n$400\nGtx 1650 Overclocked Gaming Pc\nSanta Rosa, CA'},
#  {'url': '/marketplace/item/1500335127847201/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$400\nRyzen 5 RTX 3060 Gaming PC\nDublin, CA'},
#  {'url': '/marketplace/item/822950110538781/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$440\nGreat Gaming PC\nRedwood City, CA'},
#  {'url': '/marketplace/item/1175315670898105/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': 'Free\nTrading this high end gaming pc for a mini bike or anything just text me\nSanta Clara, CA'},
#  {'url': '/marketplace/item/1468165158413328/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$550\nGaming Pc\nPittsburg, CA'},
#  {'url': '/marketplace/item/817701460974132/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$500\niBUYPOWER i7 RTX 2060 Gaming PC\nFoster City, CA'},
#  {'url': '/marketplace/item/914755967626562/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$280\nUsed Gaming PC Parts - Intel Core i7-8700K and More\nWalnut Creek, CA'},
#  {'url': '/marketplace/item/1299890115158454/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$349\n$399\nHP Omen 880 Gaming PC-32GB ram, Nvdia 1070\nMountain View, CA'},
#  {'url': '/marketplace/item/1156324653234897/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$900\nGaming pc set up\nWalnut Creek, CA'},
#  {'url': '/marketplace/item/860566829817208/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$700\n$800\nCustom Gaming PC\nHayward, CA'},
#  {'url': '/marketplace/item/2080261992512903/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$1,500\nGaming PC 2024/25\nBerkeley, CA'},
#  {'url': '/marketplace/item/823529237302860/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$1,500\nGaming PC\nGreenbrae, CA'},
#  {'url': '/marketplace/item/1356904742558391/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$2,100\nPremium Gaming PC - RTX 5070 Ti | Ryzen 7 7800X3D | 32GB DDR5 | 2TB NVMe | 850w Gold\nSan Francisco, CA'},
#  {'url': '/marketplace/item/1197148122280872/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$550\nLiquid Cooled Gaming PC (Ryzen 5 5600, 2080 Ti, 16GB, 512GB)\nMillbrae, CA'},
#  {'url': '/marketplace/item/810250561994911/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$449\nStarter Gaming PC : Intel i7 8700K | RTX 2070 Super | 16GB 3200MHz RAM | 512GB NVME SSD\nFremont, CA'},
#  {'url': '/marketplace/item/3147225295458323/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$2,800\n$3,000\nHigh End Gaming PC\nSan Leandro, CA'},
#  {'url': '/marketplace/item/1160586512809342/?ref=search&referral_code=null&referral_story_type=post&__tn__=!%3AD',
#   'text': '$1,900\n5070Ti+7800X3D gaming PC trade for Vision Pro / 4090 / 7900XTX or for sale\nFoster City, CA'}]

# %%
# Create an empty list to store product data
extracted_data = []

for item in product_data:
    lines = item['text'].split('\n')

    # Regular expression to find numeric values
    numeric_pattern = re.compile('\d[\d,.]*')
    
    # Extracting prices
    # Iterate through lines to find the first line with numbers
    for line in lines:
        match = numeric_pattern.search(line)
        if match:    
            # Extract the first numeric value found
            price_str = match.group()
            # Convert price to float (handle commas)
            price = float(price_str.replace(',',''))
            break
    '''
    if price:
        print(f"Price extracted: {price}")
    else:
        print("price not found")
    '''
    # Extract title
    title = lines[-2]

    # Extract location
    location = lines[-1]

    # Add extracted data to a list of dictionaries
    extracted_data.append({
        'title': title,
        'price': price,
        'location': location,
        'url': re.sub(r'\?.*', '', item['url'])
    })
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/xn/w_xnr1cn1jq5m_6rgnybnsc40000gn/T/ipykernel_3546/1369819200.py:8: SyntaxWarning: invalid escape sequence '\d'
#   numeric_pattern = re.compile('\d[\d,.]*')

# %%
extracted_data
# Out:
# [{'title': 'Selling a Gaming PC!',
#   'price': 800.0,
#   'location': 'Oakland, CA',
#   'url': '/marketplace/item/1936327400277652/'},
#  {'title': 'Gaming pc',
#   'price': 800.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/901321479028474/'},
#  {'title': 'Gaming Pc',
#   'price': 800.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/810831765100576/'},
#  {'title': 'Gaming PC',
#   'price': 649.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/4211399239137993/'},
#  {'title': 'Dell OptiPlex Gaming PC',
#   'price': 250.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/826444880106126/'},
#  {'title': 'Gaming PC with a 3070ti',
#   'price': 900.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/2347540209049347/'},
#  {'title': 'High-End Gaming PC – RTX 5070, i7-12700KF, 32GB DDR5, 3TB SSD, RGB',
#   'price': 1900.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/1132546485748395/'},
#  {'title': 'GAMING PC',
#   'price': 400.0,
#   'location': 'Turlock, CA',
#   'url': '/marketplace/item/733386452439995/'},
#  {'title': 'Gaming PC – Ryzen 7 / GTX 1050 Ti / 16GB RAM / 1TB – Great Starter Build',
#   'price': 300.0,
#   'location': 'Pittsburg, CA',
#   'url': '/marketplace/item/821143860832517/'},
#  {'title': 'Gaming Pc',
#   'price': 100.0,
#   'location': 'Livermore, CA',
#   'url': '/marketplace/item/814885354858152/'},
#  {'title': 'GTX 1660 ti, Ryzen 5 3600 Gaming PC',
#   'price': 300.0,
#   'location': 'Daly City, CA',
#   'url': '/marketplace/item/2340733113065321/'},
#  {'title': 'RX 580 Gaming PC',
#   'price': 250.0,
#   'location': 'Oakland, CA',
#   'url': '/marketplace/item/1145219074420994/'},
#  {'title': 'Brand new High End Gaming PC - Nvidia RTX 5080 / AMD 9800x3d',
#   'price': 2999.0,
#   'location': 'Hayward, CA',
#   'url': '/marketplace/item/1603077891123313/'},
#  {'title': 'Incomplete gaming PC project',
#   'price': 30.0,
#   'location': 'Benicia, CA',
#   'url': '/marketplace/item/1548897519465645/'},
#  {'title': 'Gaming PC',
#   'price': 1000.0,
#   'location': 'Fresno, CA',
#   'url': '/marketplace/item/1766347714079720/'},
#  {'title': 'iBUYPOWER Pro Gaming PC (+ Free monitor!) | i9-9900K, RTX 2070 8GB',
#   'price': 449.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/1166447678336128/'},
#  {'title': 'Custom Gaming PC // i7-12700k // 32GB RAM //1080 GTX',
#   'price': 525.0,
#   'location': 'El Cerrito, CA',
#   'url': '/marketplace/item/4107574722722717/'},
#  {'title': 'Gaming PC Computers for sale (3)! esports up to AAA 4k performance!',
#   'price': 875.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/808432582101480/'},
#  {'title': 'Gaming pc',
#   'price': 200.0,
#   'location': 'Fairfield, CA',
#   'url': '/marketplace/item/1200893358635057/'},
#  {'title': 'Gaming PC AMD 5700x / MSI 3070 GPU',
#   'price': 650.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/1202289165053637/'},
#  {'title': 'High-End Gaming PC – i7-9700K – TITAN X 12 GB – 32 GB RAM – 2 TB SSD – 1440p / 4K',
#   'price': 600.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/1342125647645733/'},
#  {'title': 'VENGEANCE Prebuilt Gaming PC',
#   'price': 3300.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/1361103482261687/'},
#  {'title': 'GAMING PC - i7 11700K - RTX 3060 12GB',
#   'price': 795.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/842281425151549/'},
#  {'title': 'Gaming pc gtx1080 comes with monitor keyboard mouse',
#   'price': 450.0,
#   'location': 'Fairfield, CA',
#   'url': '/marketplace/item/1546250043374782/'},
#  {'title': 'Custom Gaming PC Built for Any Budget',
#   'price': 1.0,
#   'location': 'Santa Rosa, CA',
#   'url': '/marketplace/item/1267204801796462/'},
#  {'title': 'Gtx 1650 Overclocked Gaming Pc',
#   'price': 300.0,
#   'location': 'Santa Rosa, CA',
#   'url': '/marketplace/item/848911157696743/'},
#  {'title': 'Ryzen 5 RTX 3060 Gaming PC',
#   'price': 400.0,
#   'location': 'Dublin, CA',
#   'url': '/marketplace/item/1500335127847201/'},
#  {'title': 'Great Gaming PC',
#   'price': 440.0,
#   'location': 'Redwood City, CA',
#   'url': '/marketplace/item/822950110538781/'},
#  {'title': 'Trading this high end gaming pc for a mini bike or anything just text me',
#   'price': 440.0,
#   'location': 'Santa Clara, CA',
#   'url': '/marketplace/item/1175315670898105/'},
#  {'title': 'Gaming Pc',
#   'price': 550.0,
#   'location': 'Pittsburg, CA',
#   'url': '/marketplace/item/1468165158413328/'},
#  {'title': 'iBUYPOWER i7 RTX 2060 Gaming PC',
#   'price': 500.0,
#   'location': 'Foster City, CA',
#   'url': '/marketplace/item/817701460974132/'},
#  {'title': 'Used Gaming PC Parts - Intel Core i7-8700K and More',
#   'price': 280.0,
#   'location': 'Walnut Creek, CA',
#   'url': '/marketplace/item/914755967626562/'},
#  {'title': 'HP Omen 880 Gaming PC-32GB ram, Nvdia 1070',
#   'price': 349.0,
#   'location': 'Mountain View, CA',
#   'url': '/marketplace/item/1299890115158454/'},
#  {'title': 'Gaming pc set up',
#   'price': 900.0,
#   'location': 'Walnut Creek, CA',
#   'url': '/marketplace/item/1156324653234897/'},
#  {'title': 'Custom Gaming PC',
#   'price': 700.0,
#   'location': 'Hayward, CA',
#   'url': '/marketplace/item/860566829817208/'},
#  {'title': 'Gaming PC 2024/25',
#   'price': 1500.0,
#   'location': 'Berkeley, CA',
#   'url': '/marketplace/item/2080261992512903/'},
#  {'title': 'Gaming PC',
#   'price': 1500.0,
#   'location': 'Greenbrae, CA',
#   'url': '/marketplace/item/823529237302860/'},
#  {'title': 'Premium Gaming PC - RTX 5070 Ti | Ryzen 7 7800X3D | 32GB DDR5 | 2TB NVMe | 850w Gold',
#   'price': 2100.0,
#   'location': 'San Francisco, CA',
#   'url': '/marketplace/item/1356904742558391/'},
#  {'title': 'Liquid Cooled Gaming PC (Ryzen 5 5600, 2080 Ti, 16GB, 512GB)',
#   'price': 550.0,
#   'location': 'Millbrae, CA',
#   'url': '/marketplace/item/1197148122280872/'},
#  {'title': 'Starter Gaming PC : Intel i7 8700K | RTX 2070 Super | 16GB 3200MHz RAM | 512GB NVME SSD',
#   'price': 449.0,
#   'location': 'Fremont, CA',
#   'url': '/marketplace/item/810250561994911/'},
#  {'title': 'High End Gaming PC',
#   'price': 2800.0,
#   'location': 'San Leandro, CA',
#   'url': '/marketplace/item/3147225295458323/'},
#  {'title': '5070Ti+7800X3D gaming PC trade for Vision Pro / 4090 / 7900XTX or for sale',
#   'price': 1900.0,
#   'location': 'Foster City, CA',
#   'url': '/marketplace/item/1160586512809342/'}]
